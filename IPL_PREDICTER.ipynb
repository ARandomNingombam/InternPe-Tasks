# %% [markdown]
# <a href="https://colab.research.google.com/github/ARandomNingombam/InternPe-Tasks/blob/main/IPL_PREDICTER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
d=pd.read_csv('/content/Players - Sheet1.csv')

# %%
d
# Out:
#         Player_Name        DOB Batting_Hand           Bowling_Skill   Country
# 0    A Ashish Reddy  24-Feb-91   Right_Hand        Right-arm medium     India
# 1        A Chandila   5-Dec-83   Right_Hand      Right-arm offbreak     India
# 2          A Chopra  19-Sep-77   Right_Hand      Right-arm offbreak     India
# 3       A Choudhary        NaN   Right_hand    Left-arm fast-medium       NaN
# 4       A Dananjaya        NaN   Right_Hand      Right-arm offbreak       NaN
# ..              ...        ...          ...                     ...       ...
# 561     Younis Khan  29-Nov-77   Right_Hand        Right-arm medium  Pakistan
# 562       YS Chahal  23-Jul-90   Right_Hand         Legbreak googly     India
# 563    Yuvraj Singh  12-Dec-81    Left_Hand  Slow left-arm orthodox     India
# 564     YV Takawale   5-Nov-84   Right_Hand                     NaN     India
# 565          Z Khan   7-Oct-78   Right_Hand    Left-arm fast-medium     India
#
# [566 rows x 5 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player_Name    566 non-null    object
#  1   DOB            471 non-null    object
#  2   Batting_Hand   563 non-null    object
#  3   Bowling_Skill  502 non-null    object
#  4   Country        471 non-null    object
# dtypes: object(5)
# memory usage: 22.2+ KB

# %%
delivery=pd.read_csv('/content/deliveries.csv')

# %%
matches = pd.read_csv('/content/matches.csv')

# %%
delivery
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %%
total_score=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score=total_score[total_score['inning'] == 1]

# %%
matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
match_data=matches.merge(total_score[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_data['team1']=match_data['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_data['team2']=match_data['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
match_data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_data['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Deccan Chargers', 'Chennai Super Kings', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Rising Pune Supergiant',
#        'Punjab Kings', 'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = [
     'Chennai Super Kings',
     'Delhi Capitals',
     'Gujarat Titans',
     'Kolkata Knight Riders',
     'Lucknow Super Giants',
     'Mumbai Indians',
     'Punjab Kings',
     'Rajasthan Royals',
     'Royal Challengers Bengaluru',
     'Sunrisers Hyderabad'
]

# %%
match_data=match_data[match_data['team1'].isin(teams)]

# %%
match_data=match_data[match_data['team2'].isin(teams)]

# %%
match_data
# Out:
#            id   season       city        date   match_type  player_of_match  \
# 2      335984  2007/08      Delhi  2008-04-19       League      MF Maharoof
# 7      335989  2007/08    Chennai  2008-04-23       League        ML Hayden
# 11     335993  2007/08    Chennai  2008-04-26       League         JDP Oram
# 15     335997  2007/08    Kolkata  2008-04-29       League    ST Jayasuriya
# 18     336000  2007/08     Jaipur  2008-05-01       League      SA Asnodkar
# ...       ...      ...        ...         ...          ...              ...
# 1090  1426307     2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024    Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs'],
#       dtype='object')

# %%
match_data=match_data[['match_id','city','winner','total_runs']]

# %%
delivery_data=match_data.merge(delivery,on='match_id')

# %%
delivery_data
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 0         335984    Delhi       Delhi Daredevils           129       1
# 1         335984    Delhi       Delhi Daredevils           129       1
# 2         335984    Delhi       Delhi Daredevils           129       1
# 3         335984    Delhi       Delhi Daredevils           129       1
# 4         335984    Delhi       Delhi Daredevils           129       1
# ...          ...      ...                    ...           ...     ...
# 133728   1426312  Chennai  Kolkata Knight Riders           113       2
# 133729   1426312  Chennai  Kolkata Knight Riders           113       2
# 133730   1426312  Chennai  Kolkata Knight Riders           113       2
# 133731   1426312  Chennai  Kolkata Knight Riders           113       2
# 133732   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball   batter  \
# ...

# %%
delivery_data=delivery_data[delivery_data['inning']==2]

# %%
delivery_data.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs_y', 'extras_type',
#        'is_wicket', 'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
delivery_data
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 122       335984    Delhi       Delhi Daredevils           129       2
# 123       335984    Delhi       Delhi Daredevils           129       2
# 124       335984    Delhi       Delhi Daredevils           129       2
# 125       335984    Delhi       Delhi Daredevils           129       2
# 126       335984    Delhi       Delhi Daredevils           129       2
# ...          ...      ...                    ...           ...     ...
# 133728   1426312  Chennai  Kolkata Knight Riders           113       2
# 133729   1426312  Chennai  Kolkata Knight Riders           113       2
# 133730   1426312  Chennai  Kolkata Knight Riders           113       2
# 133731   1426312  Chennai  Kolkata Knight Riders           113       2
# 133732   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball     batter  \
# ...

# %%
delivery_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64417 entries, 122 to 133732
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          64417 non-null  int64
#  1   city              61224 non-null  object
#  2   winner            64417 non-null  object
#  3   total_runs_x      64417 non-null  int64
#  4   inning            64417 non-null  int64
#  5   batting_team      64417 non-null  object
#  6   bowling_team      64417 non-null  object
#  7   over              64417 non-null  int64
#  8   ball              64417 non-null  int64
#  9   batter            64417 non-null  object
#  10  bowler            64417 non-null  object
#  11  non_striker       64417 non-null  object
#  12  batsman_runs      64417 non-null  int64
#  13  extra_runs        64417 non-null  int64
#  14  total_runs_y      64417 non-null  int64
#  15  extras_type       3436 non-null   object
# ...

# %%
delivery_data['current_score']=delivery_data.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# /tmp/ipython-input-2310278611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['current_score']=delivery_data.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_data
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 122       335984    Delhi       Delhi Daredevils           129       2
# 123       335984    Delhi       Delhi Daredevils           129       2
# 124       335984    Delhi       Delhi Daredevils           129       2
# 125       335984    Delhi       Delhi Daredevils           129       2
# 126       335984    Delhi       Delhi Daredevils           129       2
# ...          ...      ...                    ...           ...     ...
# 133728   1426312  Chennai  Kolkata Knight Riders           113       2
# 133729   1426312  Chennai  Kolkata Knight Riders           113       2
# 133730   1426312  Chennai  Kolkata Knight Riders           113       2
# 133731   1426312  Chennai  Kolkata Knight Riders           113       2
# 133732   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball     batter  \
# ...

# %%
delivery_data['runs_left_to_score']=delivery_data['total_runs_x']-delivery_data['current_score']
# Out:
# /tmp/ipython-input-1656401715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['runs_left_to_score']=delivery_data['total_runs_x']-delivery_data['current_score']

# %%
delivery_data['runs_left_to_score']
# Out:
# 122       129
# 123       129
# 124       129
# 125       129
# 126       125
#          ...
# 133728      3
# 133729      2
# 133730      1
# 133731      0
# 133732     -1
# Name: runs_left_to_score, Length: 64417, dtype: int64

# %%
delivery_data['balls_left'] = 120 - (delivery_data['over'] * 6 + delivery_data['ball'])
# Out:
# /tmp/ipython-input-2354640622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['balls_left'] = 120 - (delivery_data['over'] * 6 + delivery_data['ball'])

# %%
delivery_data
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 122       335984    Delhi       Delhi Daredevils           129       2
# 123       335984    Delhi       Delhi Daredevils           129       2
# 124       335984    Delhi       Delhi Daredevils           129       2
# 125       335984    Delhi       Delhi Daredevils           129       2
# 126       335984    Delhi       Delhi Daredevils           129       2
# ...          ...      ...                    ...           ...     ...
# 133728   1426312  Chennai  Kolkata Knight Riders           113       2
# 133729   1426312  Chennai  Kolkata Knight Riders           113       2
# 133730   1426312  Chennai  Kolkata Knight Riders           113       2
# 133731   1426312  Chennai  Kolkata Knight Riders           113       2
# 133732   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball     batter  \
# ...

# %%
delivery_data['player_dismissed']=delivery_data['player_dismissed'].fillna('0')
delivery_data['player_dismissed']=delivery_data['player_dismissed'].apply(lambda x:x if x=='0' else '1')
delivery_data['player_dismissed']=delivery_data['player_dismissed'].astype('int')
# Out:
# /tmp/ipython-input-530931558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['player_dismissed']=delivery_data['player_dismissed'].fillna('0')
# /tmp/ipython-input-530931558.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['player_dismissed']=delivery_data['player_dismissed'].apply(lambda x:x if x=='0' else '1')
# /tmp/ipython-input-530931558.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
wickets=delivery_data.groupby('match_id')['player_dismissed'].cumsum().values

# %%
delivery_data['wickets_left']=10-wickets
# Out:
# /tmp/ipython-input-1765766218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['wickets_left']=10-wickets

# %%
delivery_data
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 122       335984    Delhi       Delhi Daredevils           129       2
# 123       335984    Delhi       Delhi Daredevils           129       2
# 124       335984    Delhi       Delhi Daredevils           129       2
# 125       335984    Delhi       Delhi Daredevils           129       2
# 126       335984    Delhi       Delhi Daredevils           129       2
# ...          ...      ...                    ...           ...     ...
# 133728   1426312  Chennai  Kolkata Knight Riders           113       2
# 133729   1426312  Chennai  Kolkata Knight Riders           113       2
# 133730   1426312  Chennai  Kolkata Knight Riders           113       2
# 133731   1426312  Chennai  Kolkata Knight Riders           113       2
# 133732   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball     batter  \
# ...

# %%
delivery_data.tail()
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 133728   1426312  Chennai  Kolkata Knight Riders           113       2
# 133729   1426312  Chennai  Kolkata Knight Riders           113       2
# 133730   1426312  Chennai  Kolkata Knight Riders           113       2
# 133731   1426312  Chennai  Kolkata Knight Riders           113       2
# 133732   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball   batter  ...  \
# 133728  Kolkata Knight Riders  Sunrisers Hyderabad     9     5  SS Iyer  ...
# 133729  Kolkata Knight Riders  Sunrisers Hyderabad     9     6  VR Iyer  ...
# 133730  Kolkata Knight Riders  Sunrisers Hyderabad    10     1  VR Iyer  ...
# 133731  Kolkata Knight Riders  Sunrisers Hyderabad    10     2  SS Iyer  ...
# 133732  Kolkata Knight Riders  Sunrisers Hyderabad    10     3  VR Iyer  ...
#
# ...

# %%
delivery_data.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs_y', 'extras_type',
#        'is_wicket', 'player_dismissed', 'dismissal_kind', 'fielder',
#        'current_score', 'runs_left_to_score', 'balls_left', 'wickets_left'],
#       dtype='object')

# %%
delivery_data=delivery_data[delivery_data['balls_left']!=0]

# %%
delivery_data['crr']=(delivery_data['current_score']*6)/(120-delivery_data['balls_left'])
# Out:
# /tmp/ipython-input-4063055500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['crr']=(delivery_data['current_score']*6)/(120-delivery_data['balls_left'])

# %%
delivery_data['rrr']=(delivery_data['runs_left_to_score']*6)/(delivery_data['balls_left'])
# Out:
# /tmp/ipython-input-2208855039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['rrr']=(delivery_data['runs_left_to_score']*6)/(delivery_data['balls_left'])

# %%
def result(row):
  return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_data['result']=delivery_data.apply(result,axis=1)
# Out:
# /tmp/ipython-input-2666569100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_data['result']=delivery_data.apply(result,axis=1)

# %%
final_data=delivery_data[['batting_team','bowling_team','city','runs_left_to_score','balls_left','total_runs_x','crr','rrr','result']]

# %%
final_data=final_data.sample(final_data.shape[0])

# %%
final_data.dropna(inplace=True)

# %%
final_data=final_data[final_data['balls_left']!=0]

# %% [markdown]
# # DATA SPLITTING AND FEATURE ENGINEERING

# %%
from sklearn.model_selection import train_test_split

# %%
x=final_data.iloc[:,:-1]
y=final_data.iloc[:,-1]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
xtrain
# Out:
#                  batting_team           bowling_team       city  \
# 5445    Kolkata Knight Riders       Rajasthan Royals  Cape Town
# 21664   Kolkata Knight Riders         Mumbai Indians    Kolkata
# 91668   Kolkata Knight Riders         Delhi Capitals     Mumbai
# 27479   Kolkata Knight Riders    Chennai Super Kings    Chennai
# 102975    Sunrisers Hyderabad       Rajasthan Royals  Hyderabad
# ...                       ...                    ...        ...
# 77680     Sunrisers Hyderabad  Kolkata Knight Riders    Chennai
# 57678     Sunrisers Hyderabad       Delhi Daredevils  Hyderabad
# 61270   Kolkata Knight Riders    Sunrisers Hyderabad    Kolkata
# 11539   Kolkata Knight Riders       Delhi Daredevils      Delhi
# 77602     Sunrisers Hyderabad  Kolkata Knight Riders    Chennai
#
#         runs_left_to_score  balls_left  total_runs_x       crr         rrr
# 5445                   125          94           150  5.769231    7.978723
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
trf=ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough'
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline as p

# %%
pipe=p(
    steps=[
        ('step1',trf),
        ('step2',LogisticRegression(solver='liblinear'))
    ]
)

# %%
pipe.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
xtrain.describe()
# Out:
#        runs_left_to_score    balls_left  total_runs_x           crr  \
# count        48813.000000  48813.000000  48813.000000  48813.000000
# mean            94.474587     62.940364    170.012824      7.710790
# std             51.251566     33.192258     31.532439      2.401459
# min             -6.000000     -3.000000     67.000000      0.000000
# 25%             54.000000     35.000000    149.000000      6.500000
# 50%             93.000000     64.000000    168.000000      7.714286
# 75%            132.000000     92.000000    189.000000      9.000000
# max            286.000000    119.000000    287.000000     36.000000
#
#                 rrr
# count  48813.000000
# mean      10.462487
# std       12.892740
# min     -462.000000
# 25%        7.230769
# 50%        9.000000
# 75%       11.189189
# max      462.000000

# %%
ypred=pipe.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.8196492953130121

# %% [markdown]
# # WE HAVE ACHEIVED A SCORE OF 81% ACCURACY WITH LOGISTIC REGRESSION

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest_pipe=p(
    steps=[
        ('step1',trf),
        ('step2',RandomForestClassifier())
    ]
)

# %%
forest_pipe.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
forest_ypred=pipe.predict(xtest)

# %% [markdown]
# # A score of 81% accuracy was achieved here as well using RandomForest

# %%
accuracy_score(ytest,forest_ypred)
# Out:
# 0.8196492953130121
